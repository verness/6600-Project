# %%
import wfdb

record_path = "../Data/mit-bih-arrhythmia-database-1.0.0/100"

record = wfdb.rdrecord(record_path)
annotation = wfdb.rdann(record_path, 'atr')

print(record.p_signal.shape)   # (samples, channels)
print(annotation.symbol[:20])  # labels
print(annotation.sample[:20])  # positions
# Out:
# (650000, 2)
# ['+', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'A', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N']
# [  18   77  370  662  946 1231 1515 1809 2044 2402 2706 2998 3282 3560
#  3862 4170 4466 4764 5060 5346]

# %% [markdown]
# ## Visualizing ECG

# %%
wfdb.plot_wfdb(record=record, annotation=annotation)

# %% [markdown]
# ## Understanding Annotation Labels

# %%
set(annotation.symbol)
# Out:
# {'+', 'A', 'N', 'V'}
